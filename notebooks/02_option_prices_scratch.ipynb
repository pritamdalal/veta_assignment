# %%
import numpy as np
import pandas as pd

# %%
df_holdings = pd.read_csv("../data/etf_holdings_clean.csv")
df_holdings
# Out:
#            Date Account  Underlying MaturityDate  StrikePrice Type     Price
# 0    2024-07-12    APRT         SPY   2025-03-31         3.87    C  553.2247  \
# 1    2024-07-12    APRT         SPY   2025-03-31       617.33    C    8.6830
# 2    2024-07-12    APRT         SPY   2025-03-31       470.76    P    5.1659
# 3    2024-07-12    APRT         SPY   2025-03-31       523.02    P   10.6462
# 4    2024-07-12    APRT  Cash&Other          NaN          NaN  NaN    1.0000
# ..          ...     ...         ...          ...          ...  ...       ...
# 169  2024-07-12    SIXZ         SPY   2024-10-31         3.71    C  555.1102
# 170  2024-07-12    SIXZ         SPY   2024-10-31       543.69    C   31.0701
# 171  2024-07-12    SIXZ         SPY   2024-10-31       451.78    P    1.0376
# 172  2024-07-12    SIXZ         SPY   2024-10-31       501.93    P    2.6020
# 173  2024-07-12    SIXZ  Cash&Other          NaN          NaN  NaN    1.0000
#
#        Shares   MarketValue Weightings  SharesOutstanding
# 0     2129.00  1.177815e+08    100.65%            3175000
# 1    -2129.00 -1.848611e+06     -1.58%            3175000
# 2    -2129.00 -1.099820e+06     -0.94%            3175000
# 3     2129.00  2.266576e+06      1.94%            3175000
# 4   -91551.78 -9.155178e+04     -0.08%            3175000
# ..        ...           ...        ...                ...
# 169    150.00  8.326653e+06    105.44%             300000
# 170   -150.00 -4.660515e+05     -5.90%             300000
# 171   -150.00 -1.556400e+04     -0.20%             300000
# 172    150.00  3.903000e+04      0.49%             300000
# 173  12395.67  1.239567e+04      0.16%             300000
#
# [174 rows x 11 columns]

# %% [markdown]
# ## Adding `D2X` Column

# %%
from bizdays import Calendar
cal = Calendar.load("PMC/NYSE")

# %%
def bizdays(row):
    from_date = row["Date"]
    to_date = row["MaturityDate"]
    return cal.bizdays(from_date, to_date)

# %%
df_holdings["D2X"] = df_holdings.apply(bizdays, axis=1)
df_holdings
# Out:
#            Date Account  Underlying MaturityDate  StrikePrice Type     Price
# 0    2024-07-12    APRT         SPY   2025-03-31         3.87    C  553.2247  \
# 1    2024-07-12    APRT         SPY   2025-03-31       617.33    C    8.6830
# 2    2024-07-12    APRT         SPY   2025-03-31       470.76    P    5.1659
# 3    2024-07-12    APRT         SPY   2025-03-31       523.02    P   10.6462
# 4    2024-07-12    APRT  Cash&Other          NaN          NaN  NaN    1.0000
# ..          ...     ...         ...          ...          ...  ...       ...
# 169  2024-07-12    SIXZ         SPY   2024-10-31         3.71    C  555.1102
# 170  2024-07-12    SIXZ         SPY   2024-10-31       543.69    C   31.0701
# 171  2024-07-12    SIXZ         SPY   2024-10-31       451.78    P    1.0376
# 172  2024-07-12    SIXZ         SPY   2024-10-31       501.93    P    2.6020
# 173  2024-07-12    SIXZ  Cash&Other          NaN          NaN  NaN    1.0000
#
#        Shares   MarketValue Weightings  SharesOutstanding    D2X
# 0     2129.00  1.177815e+08    100.65%            3175000  180.0
# 1    -2129.00 -1.848611e+06     -1.58%            3175000  180.0
# 2    -2129.00 -1.099820e+06     -0.94%            3175000  180.0
# 3     2129.00  2.266576e+06      1.94%            3175000  180.0
# 4   -91551.78 -9.155178e+04     -0.08%            3175000    NaN
# ..        ...           ...        ...                ...    ...
# 169    150.00  8.326653e+06    105.44%             300000   78.0
# 170   -150.00 -4.660515e+05     -5.90%             300000   78.0
# 171   -150.00 -1.556400e+04     -0.20%             300000   78.0
# 172    150.00  3.903000e+04      0.49%             300000   78.0
# 173  12395.67  1.239567e+04      0.16%             300000    NaN
#
# [174 rows x 12 columns]

# %% [markdown]
# ## Adding `UPX` Column

# %%
df_spy = pd.read_csv("../data/spy.csv")
df_spy.dropna(inplace=True)
df_holdings["UPX"] = df_spy.query("date == '7/12/2024'").reset_index()['spy'][0]
df_holdings
# Out:
#            Date Account  Underlying MaturityDate  StrikePrice Type     Price
# 0    2024-07-12    APRT         SPY   2025-03-31         3.87    C  553.2247  \
# 1    2024-07-12    APRT         SPY   2025-03-31       617.33    C    8.6830
# 2    2024-07-12    APRT         SPY   2025-03-31       470.76    P    5.1659
# 3    2024-07-12    APRT         SPY   2025-03-31       523.02    P   10.6462
# 4    2024-07-12    APRT  Cash&Other          NaN          NaN  NaN    1.0000
# ..          ...     ...         ...          ...          ...  ...       ...
# 169  2024-07-12    SIXZ         SPY   2024-10-31         3.71    C  555.1102
# 170  2024-07-12    SIXZ         SPY   2024-10-31       543.69    C   31.0701
# 171  2024-07-12    SIXZ         SPY   2024-10-31       451.78    P    1.0376
# 172  2024-07-12    SIXZ         SPY   2024-10-31       501.93    P    2.6020
# 173  2024-07-12    SIXZ  Cash&Other          NaN          NaN  NaN    1.0000
#
#        Shares   MarketValue Weightings  SharesOutstanding    D2X     UPX
# 0     2129.00  1.177815e+08    100.65%            3175000  180.0  559.99
# 1    -2129.00 -1.848611e+06     -1.58%            3175000  180.0  559.99
# 2    -2129.00 -1.099820e+06     -0.94%            3175000  180.0  559.99
# 3     2129.00  2.266576e+06      1.94%            3175000  180.0  559.99
# 4   -91551.78 -9.155178e+04     -0.08%            3175000    NaN  559.99
# ..        ...           ...        ...                ...    ...     ...
# 169    150.00  8.326653e+06    105.44%             300000   78.0  559.99
# 170   -150.00 -4.660515e+05     -5.90%             300000   78.0  559.99
# 171   -150.00 -1.556400e+04     -0.20%             300000   78.0  559.99
# 172    150.00  3.903000e+04      0.49%             300000   78.0  559.99
# 173  12395.67  1.239567e+04      0.16%             300000    NaN  559.99
#
# [174 rows x 13 columns]

# %% [markdown]
# ## Adding `Moneyness` Column

# %%
df_holdings["Moneyness"] = df_holdings["StrikePrice"] / df_holdings["UPX"]
#df_holdings["Moneyness"] = df_holdings["UPX"] / df_holdings["StrikePrice"]
df_holdings
# Out:
#            Date Account  Underlying MaturityDate  StrikePrice Type     Price
# 0    2024-07-12    APRT         SPY   2025-03-31         3.87    C  553.2247  \
# 1    2024-07-12    APRT         SPY   2025-03-31       617.33    C    8.6830
# 2    2024-07-12    APRT         SPY   2025-03-31       470.76    P    5.1659
# 3    2024-07-12    APRT         SPY   2025-03-31       523.02    P   10.6462
# 4    2024-07-12    APRT  Cash&Other          NaN          NaN  NaN    1.0000
# ..          ...     ...         ...          ...          ...  ...       ...
# 169  2024-07-12    SIXZ         SPY   2024-10-31         3.71    C  555.1102
# 170  2024-07-12    SIXZ         SPY   2024-10-31       543.69    C   31.0701
# 171  2024-07-12    SIXZ         SPY   2024-10-31       451.78    P    1.0376
# 172  2024-07-12    SIXZ         SPY   2024-10-31       501.93    P    2.6020
# 173  2024-07-12    SIXZ  Cash&Other          NaN          NaN  NaN    1.0000
#
#        Shares   MarketValue Weightings  SharesOutstanding    D2X     UPX
# 0     2129.00  1.177815e+08    100.65%            3175000  180.0  559.99  \
# 1    -2129.00 -1.848611e+06     -1.58%            3175000  180.0  559.99
# 2    -2129.00 -1.099820e+06     -0.94%            3175000  180.0  559.99
# 3     2129.00  2.266576e+06      1.94%            3175000  180.0  559.99
# 4   -91551.78 -9.155178e+04     -0.08%            3175000    NaN  559.99
# ..        ...           ...        ...                ...    ...     ...
# 169    150.00  8.326653e+06    105.44%             300000   78.0  559.99
# 170   -150.00 -4.660515e+05     -5.90%             300000   78.0  559.99
# 171   -150.00 -1.556400e+04     -0.20%             300000   78.0  559.99
# 172    150.00  3.903000e+04      0.49%             300000   78.0  559.99
# 173  12395.67  1.239567e+04      0.16%             300000    NaN  559.99
#
#      Moneyness
# 0     0.006911
# 1     1.102395
# 2     0.840658
# 3     0.933981
# 4          NaN
# ..         ...
# 169   0.006625
# 170   0.970892
# 171   0.806764
# 172   0.896320
# 173        NaN
#
# [174 rows x 14 columns]

# %% [markdown]
# ## Adding `RF` Column

# %%
df_risk_free = pd.read_csv("../data/rates.csv")
df_risk_free.head()
# Out:
#   ObservationDate CurveTicker  ComponentTicker TenorString  D2X   Close
# 0       7/12/2024    YCSW0042  USSO1Day Curncy          1D    1  5.3294  \
# 1       7/12/2024    YCSW0042    USSO1Z Curncy          1W    5  5.3294
# 2       7/12/2024    YCSW0042    USSO2Z Curncy          2W   10  5.3322
# 3       7/12/2024    YCSW0042    USSO3Z Curncy          3W   15  5.3320
# 4       7/12/2024    YCSW0042     USSOA Curncy          1M   21  5.3329
#
#     TenorEnd
# 0  7/13/2024
# 1  4/11/2024
# 2  4/18/2024
# 3  4/25/2024
# 4   5/4/2024

# %%
def risk_free(row):
    d2x = row["D2X"]
    return np.interp(d2x, df_risk_free["D2X"], df_risk_free["Close"])

# %%
df_holdings["RF"] = df_holdings.apply(risk_free, axis=1) / 100
df_holdings
# Out:
#            Date Account  Underlying MaturityDate  StrikePrice Type     Price
# 0    2024-07-12    APRT         SPY   2025-03-31         3.87    C  553.2247  \
# 1    2024-07-12    APRT         SPY   2025-03-31       617.33    C    8.6830
# 2    2024-07-12    APRT         SPY   2025-03-31       470.76    P    5.1659
# 3    2024-07-12    APRT         SPY   2025-03-31       523.02    P   10.6462
# 4    2024-07-12    APRT  Cash&Other          NaN          NaN  NaN    1.0000
# ..          ...     ...         ...          ...          ...  ...       ...
# 169  2024-07-12    SIXZ         SPY   2024-10-31         3.71    C  555.1102
# 170  2024-07-12    SIXZ         SPY   2024-10-31       543.69    C   31.0701
# 171  2024-07-12    SIXZ         SPY   2024-10-31       451.78    P    1.0376
# 172  2024-07-12    SIXZ         SPY   2024-10-31       501.93    P    2.6020
# 173  2024-07-12    SIXZ  Cash&Other          NaN          NaN  NaN    1.0000
#
#        Shares   MarketValue Weightings  SharesOutstanding    D2X     UPX
# 0     2129.00  1.177815e+08    100.65%            3175000  180.0  559.99  \
# 1    -2129.00 -1.848611e+06     -1.58%            3175000  180.0  559.99
# 2    -2129.00 -1.099820e+06     -0.94%            3175000  180.0  559.99
# 3     2129.00  2.266576e+06      1.94%            3175000  180.0  559.99
# 4   -91551.78 -9.155178e+04     -0.08%            3175000    NaN  559.99
# ..        ...           ...        ...                ...    ...     ...
# 169    150.00  8.326653e+06    105.44%             300000   78.0  559.99
# 170   -150.00 -4.660515e+05     -5.90%             300000   78.0  559.99
# 171   -150.00 -1.556400e+04     -0.20%             300000   78.0  559.99
# 172    150.00  3.903000e+04      0.49%             300000   78.0  559.99
# 173  12395.67  1.239567e+04      0.16%             300000    NaN  559.99
#
#      Moneyness        RF
# 0     0.006911  0.049883
# 1     1.102395  0.049883
# 2     0.840658  0.049883
# 3     0.933981  0.049883
# 4          NaN       NaN
# ..         ...       ...
# 169   0.006625  0.052484
# 170   0.970892  0.052484
# 171   0.806764  0.052484
# 172   0.896320  0.052484
# 173        NaN       NaN
#
# [174 rows x 15 columns]

# %% [markdown]
# ## Adding `DIV` Column

# %%
df_dividend = pd.read_csv("../data/spx_dividend.csv")
#df_dividend['DivCurve'] = df_dividend['DivCurve'][:-2]
df_dividend.head()
# Out:
#   DivExpirationDate  DivCurve
# 0         15-Jul-24   0.02915
# 1         16-Jul-24   0.01962
# 2         17-Jul-24   0.01690
# 3         18-Jul-24   0.01133
# 4         19-Jul-24  -0.00320

# %%
df_dividend["Date"] = pd.to_datetime('2024-07-12')
#df_dividend["Date"] = pd.to_datetime(df_dividend["Date"])
df_dividend["DivExpirationDate"] = pd.to_datetime(df_dividend["DivExpirationDate"], format="mixed", dayfirst=True)
df_dividend.head()
# Out:
#   DivExpirationDate  DivCurve       Date
# 0        2024-07-15   0.02915 2024-07-12
# 1        2024-07-16   0.01962 2024-07-12
# 2        2024-07-17   0.01690 2024-07-12
# 3        2024-07-18   0.01133 2024-07-12
# 4        2024-07-19  -0.00320 2024-07-12

# %%
def bizdays(row):
    from_date = row["Date"]
    to_date = row["DivExpirationDate"]
    return cal.bizdays(from_date, to_date)

# %%
df_dividend["D2X"] = df_dividend.apply(bizdays, axis=1)
df_dividend.head()
# Out:
#   DivExpirationDate  DivCurve       Date  D2X
# 0        2024-07-15   0.02915 2024-07-12    1
# 1        2024-07-16   0.01962 2024-07-12    2
# 2        2024-07-17   0.01690 2024-07-12    3
# 3        2024-07-18   0.01133 2024-07-12    4
# 4        2024-07-19  -0.00320 2024-07-12    5

# %%
def dividend(row):
    d2x = row["D2X"]
    dividend = np.interp(d2x, df_dividend["D2X"], df_dividend["DivCurve"])
    if dividend < 0:
        dividend = 0
    return dividend

# %%
df_holdings["Div"] = df_holdings.apply(dividend, axis=1)
df_holdings
# Out:
#            Date Account  Underlying MaturityDate  StrikePrice Type     Price
# 0    2024-07-12    APRT         SPY   2025-03-31         3.87    C  553.2247  \
# 1    2024-07-12    APRT         SPY   2025-03-31       617.33    C    8.6830
# 2    2024-07-12    APRT         SPY   2025-03-31       470.76    P    5.1659
# 3    2024-07-12    APRT         SPY   2025-03-31       523.02    P   10.6462
# 4    2024-07-12    APRT  Cash&Other          NaN          NaN  NaN    1.0000
# ..          ...     ...         ...          ...          ...  ...       ...
# 169  2024-07-12    SIXZ         SPY   2024-10-31         3.71    C  555.1102
# 170  2024-07-12    SIXZ         SPY   2024-10-31       543.69    C   31.0701
# 171  2024-07-12    SIXZ         SPY   2024-10-31       451.78    P    1.0376
# 172  2024-07-12    SIXZ         SPY   2024-10-31       501.93    P    2.6020
# 173  2024-07-12    SIXZ  Cash&Other          NaN          NaN  NaN    1.0000
#
#        Shares   MarketValue Weightings  SharesOutstanding    D2X     UPX
# 0     2129.00  1.177815e+08    100.65%            3175000  180.0  559.99  \
# 1    -2129.00 -1.848611e+06     -1.58%            3175000  180.0  559.99
# 2    -2129.00 -1.099820e+06     -0.94%            3175000  180.0  559.99
# 3     2129.00  2.266576e+06      1.94%            3175000  180.0  559.99
# 4   -91551.78 -9.155178e+04     -0.08%            3175000    NaN  559.99
# ..        ...           ...        ...                ...    ...     ...
# 169    150.00  8.326653e+06    105.44%             300000   78.0  559.99
# 170   -150.00 -4.660515e+05     -5.90%             300000   78.0  559.99
# 171   -150.00 -1.556400e+04     -0.20%             300000   78.0  559.99
# 172    150.00  3.903000e+04      0.49%             300000   78.0  559.99
# 173  12395.67  1.239567e+04      0.16%             300000    NaN  559.99
#
#      Moneyness        RF      Div
# 0     0.006911  0.049883  0.00596
# 1     1.102395  0.049883  0.00596
# 2     0.840658  0.049883  0.00596
# 3     0.933981  0.049883  0.00596
# 4          NaN       NaN      NaN
# ..         ...       ...      ...
# 169   0.006625  0.052484  0.00557
# 170   0.970892  0.052484  0.00557
# 171   0.806764  0.052484  0.00557
# 172   0.896320  0.052484  0.00557
# 173        NaN       NaN      NaN
#
# [174 rows x 16 columns]

# %% [markdown]
# ## Adding `IV` Columns

# %%
df_vol_surface = pd.read_csv("../data/spx_implied_volatility.csv")
df_vol_surface

# %%
d2x = df_vol_surface["D2X"].values.reshape(12, 9).T
moneyness = df_vol_surface["Moneyness"].values.reshape(12, 9)

# %%
points = np.array(np.meshgrid(d2x[0], moneyness[0])).T.reshape(-1, 2)
points

# %%
vols = df_vol_surface["BBG"].values.reshape(12, 9) / 100
values = vols.reshape(108)
values

# %%
import scipy
from scipy.interpolate import LinearNDInterpolator
from scipy.interpolate import NearestNDInterpolator
interp = LinearNDInterpolator(points, values, fill_value=0.25)
#interp = NearestNDInterpolator(points, values, np.max(values))
#interp = scipy.interpolate.interp2d(x=points[:,0], y=points[:,1], z=values, bounds_error=False, fill_value=None)

# %%
def vol_surface(row):
    d2x = row["D2X"]
    moneyness = row["Moneyness"]
    return np.round(interp(d2x, moneyness), 4)

# %%
# need to use 2-dimensional interpolation
df_holdings["Volatility"] = df_holdings.apply(vol_surface, axis=1)
df_holdings

# %% [markdown]
# ## Calculating Prices and Greeks

# %%
from py_vollib.black_scholes_merton import black_scholes_merton
from py_vollib.black_scholes_merton.greeks.analytical import delta
from py_vollib.black_scholes_merton.greeks.analytical import vega

# %%
def bsm_px(row):
    underlying = row["Underlying"]
    if underlying == "Cash&Other":
        return(np.nan)
    
    cp = row["Type"].lower()
    upx = row["UPX"]
    strike = row["StrikePrice"]
    t2x = row["D2X"] / 252
    rf = row["RF"]
    volatility = row["Volatility"]
    q = row["Div"]
    px = black_scholes_merton(cp, upx, strike, t2x, rf, volatility, q)
    px = np.round(px, 4)
    
    return(px)

# %%
df_holdings["MyPrice"] = df_holdings.apply(bsm_px, axis=1)
df_holdings

# %%
df_holdings.plot(x='Price', y='MyPrice', kind='scatter', xlim=(0, 100), ylim=(0, 100));

# %%
def crr_vanilla(cp, K, T, S0, vol, r, q, american=False, steps=1000):
    dt = T / steps                 # length of time-step
    u = np.exp(vol * np.sqrt(dt))  # up factor
    d = 1.0 / u                    # down factor
    a = np.exp((r-q)*dt)           # growth factor
    p = (a - d) / (u - d)          # risk-neutral up probability
    disc = np.exp(-r*dt)           # discount factor

    # initializing terminal underlying values
    S = S0 * (d**np.arange(steps, -1, -1)) * (u**np.arange(0, steps+1, 1))

    # value of option at final time step
    if cp == 'put':
        V = np.maximum(0, K - S)
    else:
        V = np.maximum(0, S - K)


    # backward recursion through the tree (only to the penultimate step so we can calculate delta)
    for i in np.arange(steps-1,0,-1): 
        S = (S * u)[0:-1] # a tricky way of calculating the previous underlying prices
        V =  disc * (p*V[1:i+2] + (1-p)*V[0:i+1])
        # check for early exercise
        if american:
            if cp == 'put':
                V = np.maximum(V, K - S)
            else:
                V = np.maximum(V, S - K)

    delta = (V[1] - V[0]) / (S[1] - S[0])
    price = disc * (p*V[1] + (1-p)*V[0])
    
    return price, delta

# %%
def crr_px(row):
    underlying = row["Underlying"]
    if underlying == "Cash&Other":
        return(np.nan)
    
    cp = row["Type"].lower()
    if cp == "p":
        cp = "put"
    else:
        cp = "call"
    
    upx = row["UPX"]
    strike = row["StrikePrice"]
    t2x = row["D2X"] / 252
    rf = row["RF"]
    volatility = row["Volatility"]
    q = row["Div"]
    #px = black_scholes_merton(cp, upx, strike, t2x, rf, volatility, q)
    px = crr_vanilla(cp, strike, t2x, upx, volatility, rf, q, american=True, steps=5000)[0]
    px = np.round(px, 4)
    
    return(px)

# %%
df_holdings["MyPriceAmerican"] = df_holdings.apply(crr_px, axis=1)
df_holdings

# %%
df_holdings.plot(x='Price', y='MyPriceAmerican', kind='scatter', xlim=(0, 100), ylim=(0, 100));

# %%
df_holdings.query("MyPriceAmerican < 5").plot(x='Price', y='MyPrice', kind='scatter', xlim=(0, 5), ylim=(0, 5));

# %%
df_holdings.query("MyPriceAmerican < 5").plot(x='Price', y='MyPriceAmerican', kind='scatter', xlim=(0, 5), ylim=(0, 5));

# %%
df_holdings.query("MyPrice< 5")
